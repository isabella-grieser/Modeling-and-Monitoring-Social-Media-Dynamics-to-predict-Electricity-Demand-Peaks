# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
import gen.modelgen as mb
import networkx as nx

# %% [markdown]
# # Effects of Misinformation on the Electrical Grid

# %%
with open("./config/network_gen.json", "r") as f:
    config = json.load(f)
    print(config)

# create social media network model

# small world novel
network_model = mb.create_social_network_graph(
    20,
    "watts_strogatz",
    config["network"]
)

# plot graph
nx.draw(network_model, with_labels=True, font_weight='bold')
# Out:
# {'network': {'n': 100, 'edges': 4, 'p': 0.2, 'seed': 50, 'm': 3}}

# %%
# Barabasi Albert Network Model
network_model = mb.create_social_network_graph(
    20,
    "barabasi_albert",
    config["network"]
)

# plot graph
nx.draw(network_model, with_labels=True, font_weight='bold')

# %%
network_model = mb.create_social_network_graph(
    20,
    "erdos_renyi",
    config["network"]
)

# plot graph
nx.draw(network_model, with_labels=True, font_weight='bold')
